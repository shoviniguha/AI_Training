# %%
import pandas as pd
import matplotlib.pyplot as plt
# Sales dataset
data = {
"Month": ["Jan", "Feb", "Mar", "Jan", "Feb", "Mar", "Jan", "Feb", "Mar"],
"Product": ["Mobile", "Mobile", "Mobile", "Laptop", "Laptop", "Laptop", "TV",
"TV", "TV"],
"Units_Sold": [200, 220, 210, 120, 135, 150, 80, 95, 100],
"Revenue": [300000, 330000, 315000, 600000, 675000, 750000, 240000, 285000,
300000]
}
df = pd.DataFrame(data)
df
# Out:
#   Month Product  Units_Sold  Revenue
# 0   Jan  Mobile         200   300000
# 1   Feb  Mobile         220   330000
# 2   Mar  Mobile         210   315000
# 3   Jan  Laptop         120   600000
# 4   Feb  Laptop         135   675000
# 5   Mar  Laptop         150   750000
# 6   Jan      TV          80   240000
# 7   Feb      TV          95   285000
# 8   Mar      TV         100   300000

# %%
#TASK 1: Basic Analysis

# %%
total_revenue=df.groupby('Product')['Revenue'].sum()
average_units=df.groupby('Product')['Units_Sold'].mean()

# %%
print(total_revenue)
print(average_units)
# Out:
# Product
# Laptop    2025000
# Mobile     945000
# TV         825000
# Name: Revenue, dtype: int64
# Product
# Laptop    135.000000
# Mobile    210.000000
# TV         91.666667
# Name: Units_Sold, dtype: float64

# %%
#TASK 2: Visualization 1 – Line Chart

# %%
monthly_revenue=df.groupby(['Month','Product'])['Revenue'].sum()

# %%
monthly_revenue
# Out:
# Month  Product
# Feb    Laptop     675000
#        Mobile     330000
#        TV         285000
# Jan    Laptop     600000
#        Mobile     300000
#        TV         240000
# Mar    Laptop     750000
#        Mobile     315000
#        TV         300000
# Name: Revenue, dtype: int64

# %%
import numpy as np
monthly_revenue=np.array(monthly_revenue)
monthly_revenue
# Out:
# array([675000, 330000, 285000, 600000, 300000, 240000, 750000, 315000,
#        300000])

# %%
laptop=[]
for i in (3,0,6):
    laptop.append(monthly_revenue[i])
mobile=[]
for i in (4,1,7):
    mobile.append(monthly_revenue[i])
tv=[]
for i in (5,2,8):
    tv.append(monthly_revenue[i])

# %%
months=['Jan','Feb','Mar']

# %%
import matplotlib.pyplot as plt
plt.plot(months,laptop,label='Laptop',marker='o')
plt.plot(months,mobile,label='Mobile',marker='o')
plt.plot(months,tv,label='TV',marker='o')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=30)
plt.legend()
plt.title("Monthly Revenue Trend for each product")
plt.show()

# %%
#TASK 3- Visualization 2 – Bar Chart

# %%
rev=np.array(total_revenue)

# %%
rev
# Out:
# array([2025000,  945000,  825000])

# %%
prod=['Laptop','Mobile','TV']

# %%
plt.bar(prod,rev)
plt.title("Total Revenue per Product")
plt.xlabel('Product')
plt.ylabel('Total Revenue')
plt.xticks(rotation=30)
plt.show()

# %%
#TASK 3- Visualization 3 – Pie Chart

# %%
plt.pie(rev,labels=prod,autopct='%1.1f%%')
plt.title("Contribution of each product to total revenue")
plt.show()
